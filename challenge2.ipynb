# %% [markdown]
# ## Challenge2
#
# ### Take the 5 stocks that I picked and plot the moving averages and graph it

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
TaiwanSemi = yf.download("TSM")
Costco = yf.download("COST")
Nike = yf.download("NKE")
PG = yf.download("PG")
Nvidia = yf.download("NVDA")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
TaiwanSemi = TaiwanSemi.Close.to_frame()
TaiwanSemi
# Out:
#                 Close
# Date
# 1997-10-09   6.323565
# 1997-10-10   6.615830
# 1997-10-13   6.469698
# 1997-10-14   6.204002
# 1997-10-15   6.031299
# ...               ...
# 2022-05-24  88.720001
# 2022-05-25  90.410004
# 2022-05-26  91.000000
# 2022-05-27  93.769997
# 2022-05-31  95.300003
#
# [6201 rows x 1 columns]

# %%
TaiwanSemi.plot(figsize=(15,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
TaiwanSemi["SMA50"] = TaiwanSemi.rolling(window=50, min_periods=50).mean()

# %%
TaiwanSemi.plot(figsize=(15,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
Costco = Costco.Close.to_frame()
Costco
# Out:
#                  Close
# Date
# 1986-07-09   11.000000
# 1986-07-10   10.937500
# 1986-07-11   10.562500
# 1986-07-14   10.250000
# 1986-07-15    9.937500
# ...                ...
# 2022-05-24  437.709991
# 2022-05-25  440.109985
# 2022-05-26  464.989990
# 2022-05-27  470.760010
# 2022-05-31  466.220001
#
# [9048 rows x 1 columns]

# %%
Costco["SMA50"] = Costco.rolling(window=50, min_periods=50).mean()

# %%
Costco.plot(figsize=(15,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
Nike = Nike.Close.to_frame()
Nike
# Out:
#                  Close
# Date
# 1980-12-02    0.179688
# 1980-12-03    0.175781
# 1980-12-04    0.181641
# 1980-12-05    0.171875
# 1980-12-08    0.162109
# ...                ...
# 2022-05-24  107.290001
# 2022-05-25  108.199997
# 2022-05-26  112.940002
# 2022-05-27  115.989998
# 2022-05-31  118.849998
#
# [10463 rows x 1 columns]

# %%
Nike["SMA50"] = Nike.rolling(window=50, min_periods=50).mean()
Nike.plot(figsize=(15,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
PG = PG.Close.to_frame()
PG["SMA50"] = PG.rolling(window=50, min_periods=50).mean()
PG.plot(figsize=(15,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
Nvidia = Nvidia.Close.to_frame()
Nvidia["SMA50"] = Nvidia.rolling(window=50, min_periods=50).mean()
Nvidia.plot(figsize=(15,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()
